# %%
from keras.models import Model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b0ea6224d6fd> in <module>
# ----> 1 from keras.models import Model
#
# ModuleNotFoundError: No module named 'keras'

# %%
from keras.applications.resnet50 import ResNet50

# %%
from  keras.layers import Concatenate, Conv2D, Dense, Dropout, MaxPooling2D, Activation, BatchNormalization

# %%
import keras
import tensorflow as tf
import numpy as np

# %%
from multiprocessing import Pool
import glob
import os

# %%
from keras.layers import Input

# %%
def get_images(data_path):
    files = []
    idx = 0
    for ext in ['jpg', 'png', 'jpeg', 'JPG']:
        files.extend(glob.glob(
            os.path.join(data_path, '*.{}'.format(ext))))
        idx += 1
    return files

# %%
def get_data_process():
    img = cv2.imread(image_file)
    h, w, _ = img.shape
    txt_file = get_text_file(image_file)

# %%
def get_data():
    image_files = np.array(get_images(validation_data_path))
    images = []

# %%
data_path = 'EAST-master//train_data'

# %%
get_images(data_path)
# Out:
# ['EAST-master//train_data\\img_1.jpg',
#  'EAST-master//train_data\\img_10.jpg',
#  'EAST-master//train_data\\img_100.jpg',
#  'EAST-master//train_data\\img_1000.jpg',
#  'EAST-master//train_data\\img_100_2013.jpg',
#  'EAST-master//train_data\\img_101.jpg',
#  'EAST-master//train_data\\img_101_2013.jpg',
#  'EAST-master//train_data\\img_102.jpg',
#  'EAST-master//train_data\\img_102_2013.jpg',
#  'EAST-master//train_data\\img_103.jpg',
#  'EAST-master//train_data\\img_103_2013.jpg',
#  'EAST-master//train_data\\img_104.jpg',
#  'EAST-master//train_data\\img_104_2013.jpg',
#  'EAST-master//train_data\\img_105.jpg',
#  'EAST-master//train_data\\img_105_2013.jpg',
#  'EAST-master//train_data\\img_106.jpg',
#  'EAST-master//train_data\\img_106_2013.jpg',
#  'EAST-master//train_data\\img_107.jpg',
#  'EAST-master//train_data\\img_107_2013.jpg',
#  'EAST-master//train_data\\img_108.jpg',
#  'EAST-master//train_data\\img_108_2013.jpg',
#  'EAST-master//train_data\\img_109.jpg',
# ...

# %%
pool = Pool()

# %%
pool.map_async()

# %%
ip_image = Input(shape=(None,None,3),name='ip_image')

# %%
temp = Model()

# %%
temp.add(ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None))
